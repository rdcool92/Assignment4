# %% [markdown]
# <a href="https://colab.research.google.com/github/rdcool92/Assignment4/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# code to remove warning at top of the plot
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
# Out:
# <ipython-input-2-d0c4a47b8e66>:4: MatplotlibDeprecationWarning: mplDeprecation was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use matplotlib.MatplotlibDeprecationWarning instead.
#   warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
working_path = "/content/drive/MyDrive/Airbnb Dataset 19.csv"
df = pd.read_csv(working_path)

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (249, 16)

# %%
df.info(memory_usage = 'deep' )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              249 non-null    int64
#  1   name                            249 non-null    object
#  2   host_id                         249 non-null    int64
#  3   host_name                       249 non-null    object
#  4   neighbourhood_group             249 non-null    object
#  5   neighbourhood                   249 non-null    object
#  6   latitude                        249 non-null    float64
#  7   longitude                       249 non-null    float64
#  8   room_type                       249 non-null    object
#  9   price                           249 non-null    int64
#  10  minimum_nights                  249 non-null    int64
#  11  number_of_reviews               249 non-null    int64
# ...

# %%
data = {
    'id': [1, 2, 3, 4, 5],
    'price': [100, 150, 120, 200, 180],
    'number_of_reviews': [10, 15, 8, 20, 18],
    'availability_365': [200, 150, 180, 120, 160]
}

df = pd.DataFrame(data)

# Plotting a line chart for 'price' over 'id'
plt.plot(df['id'], df['price'], marker='o', label='Price')
plt.title('Line Chart of Price over ID')
plt.xlabel('ID')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
data = {
    'id': [1, 2, 3, 4, 5],
    'price': [100, 150, 120, 200, 180],
    'number_of_reviews': [10, 15, 8, 20, 18],
    'availability_365': [200, 150, 180, 120, 160]
}

df = pd.DataFrame(data)

# Plotting a bar chart for 'price' over 'id'
plt.bar(df['id'], df['price'], color='blue', label='Price')
plt.title('Bar Chart of Price over ID')
plt.xlabel('ID')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import plotly.express as px
import pandas as pd

# %%
data = {
    'id': [1, 2, 3, 4, 5],
    'price': [100, 150, 120, 200, 180],
    'number_of_reviews': [10, 15, 8, 20, 18],
    'availability_365': [200, 150, 180, 120, 160]
}

df = pd.DataFrame(data)

fig = px.treemap(df, path=['id'], values='price', hover_data=['number_of_reviews'])

fig.update_layout(title='Treemap of Price and Number of Reviews over ID')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import folium
from folium.plugins import HeatMap
import pandas as pd
import plotly.express as px

# %%
data = pd.DataFrame({
    'latitude': [40.7128, 34.0522, 41.8781, 37.7749, 33.4484],
    'longitude': [-74.0060, -118.2437, -87.6298, -122.4194, -112.0740]
})

# Create a density map
fig = px.density_mapbox(data, lat='latitude', lon='longitude', radius=10, zoom=10,
                        mapbox_style="carto-positron", opacity=0.8,
                        color_continuous_scale="Viridis", title='Density of room type')

fig.update_layout(width=1500, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = [10, 15, 20, 25]
y_values = [20, 25, 15, 30]
bubble_sizes = [30, 40, 25, 35]

# Create a scatter plot with bubble sizes
plt.scatter(x_values, y_values, s=bubble_sizes, alpha=0.5)

# Add labels and title
plt.xlabel('room_type')
plt.ylabel('number_of_reviews')
plt.title('Bubble Chart Example')

# Show the plot
plt.show()

# %%
data = pd.DataFrame({
    'room_type': ['Entire home/apt', 'Private room', 'Shared room', 'Hotel room'],
    'count': [100, 150, 50, 30]
})

# Create a pie chart
fig = px.pie(data, names='room_type', values='count', title='Pie Chart of Room Types')

fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = pd.DataFrame({
    'neighbourhood_group': ['A', 'B', 'C', 'D'],
    'room_type': ['Entire home/apt', 'Private room', 'Shared room', 'Hotel room'],
    'count': [10, 15, 5, 3]
})

# Create a heatmap
fig = px.imshow(data.pivot_table(index='neighbourhood_group', columns='room_type', values='count'),
                x=data['room_type'].unique(), y=data['neighbourhood_group'].unique(),
                labels=dict(color='Count'), title='Heatmap of Room Types in Neighbourhoods')

fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with the 'title' column
# Replace 'df' with your actual DataFrame name

# Sample data
data = {
    'id': [1, 2, 3, 4, 5],
    'name': ['Listing 1', 'Listing 2', 'Listing 3', 'Listing 4', 'Listing 5'],
    'title': ['Beautiful Home in City Center', 'Cozy Private Room', 'Downtown Loft with View', 'Luxury Apartment', 'Charming Cottage']
}

df = pd.DataFrame(data)

# Subsetting 'title' column
df_wordcloud = df['title']

# Joining words
text = " ".join(word for word in df_wordcloud)

# Create stopword list:
stopwords = set(STOPWORDS)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image
# The matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
data = {
    'id': [1, 2, 3, 4, 5],
    'name': ['Listing 1', 'Listing 2', 'Listing 3', 'Listing 4', 'Listing 5'],
    'neighbourhood_group': ['A', 'B', 'A', 'C', 'B'],
    'room_type': ['Entire home/apt', 'Private room', 'Entire home/apt', 'Shared room', 'Entire home/apt'],
    'price': [120, 30, 90, 45, 150],
    'minimum_nights': [2, 1, 3, 2, 4],
    'number_of_reviews': [10, 5, 15, 3, 20],
    'reviews_per_month': [1, 0.5, 1.2, 0.3, 1.5],
    'calculated_host_listings_count': [1, 1, 2, 1, 3],
    'availability_365': [200, 150, 180, 120, 160]
}

df = pd.DataFrame(data)

sns.set(style="darkgrid")

plt.figure(figsize=(8, 5))

sns.kdeplot(data=df.price[df['room_type'] == 'Entire home/apt'], shade=True)

plt.show()
# Out:
# <ipython-input-24-81e127638372>:23: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.

# %%
df = {
    'id': [1, 2, 3, 4, 5],
    'name': ['Listing 1', 'Listing 2', 'Listing 3', 'Listing 4', 'Listing 5'],
    'latitude': [40.7128, 34.0522, 41.8781, 37.7749, 33.4484],
    'longitude': [-74.0060, -118.2437, -87.6298, -122.4194, -112.0740],
    'price': [100, 150, 120, 200, 180],
    'minimum_nights': [2, 1, 3, 2, 4],
    'number_of_reviews': [10, 5, 15, 3, 20],
    'reviews_per_month': [1, 0.5, 1.2, 0.3, 1.5],
    'availability_365': [200, 150, 180, 120, 160]
}

df = pd.DataFrame(df)

# Create a scatter plot
plt.scatter(df['longitude'], df['latitude'], c=df['price'], cmap='viridis', alpha=0.5)

# Set labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Listings')

# Add colorbar
plt.colorbar(label='Price')

# Display the plot
plt.show()
